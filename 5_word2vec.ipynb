# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
          'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.679917
# Nearest to the: ecclesia, auld, tumble, innovative, aspirant, transgression, adrift, ramesses,
# Nearest to not: overload, smith, semipalatinsk, videotape, caravan, ux, festivities, haden,
# Nearest to often: serapis, creeks, samoa, abbess, sitcoms, indefinitely, levied, ensued,
# Nearest to than: needy, nixon, shapiro, kurz, masturbating, arnauld, inherent, pac,
# Nearest to are: exarch, census, winnie, annealing, giza, montreux, monogamy, denials,
# Nearest to about: jasmine, locke, rearmament, alligator, reelection, necessities, restricted, disloyalty,
# Nearest to he: tracy, aboard, clashing, relays, headset, anticonvulsants, showcasing, metrical,
# Nearest to of: adhd, uu, untso, labarum, jets, systemic, journeying, beluga,
# Nearest to when: chirac, kasparov, unhelpful, confesses, anscombe, enid, indentations, doves,
# Nearest to american: killed, infections, hartree, zeitung, satem, neko, noll, antibiotics,
# Nearest to to: organisers, preferences, douard, necker, hospitality, cambodia, columnist, supplied,
# Nearest to can: aes, johnson, famer, declensions, anemometers, ilois, stahl, lakers,
# Nearest to in: supervision, dobbs, euclidean, preparation, offices, assassinations, grooves, elegy,
# Nearest to many: glyph, cia, increased, discards, usn, maharashtra, carolla, compounding,
# Nearest to his: clipping, pools, manchus, minima, whereabouts, outsold, oslo, liguria,
# Nearest to used: deformed, torrey, kittiwake, persuasive, clos, closeness, imperative, vilified,
# Average loss at step 2000: 4.364270
# Average loss at step 4000: 3.865233
# Average loss at step 6000: 3.783595
# Average loss at step 8000: 3.687779
# Average loss at step 10000: 3.615927
# Nearest to the: its, a, this, his, democide, pompeii, their, color,
# Nearest to not: it, there, sec, they, nonaligned, altering, videotape, motorsport,
# Nearest to often: also, prerequisites, sitcoms, there, it, shine, creeks, simply,
# Nearest to than: baleen, tailed, nixon, or, harmattan, redefinition, total, munitions,
# Nearest to are: were, is, have, if, but, krzy, smuts, was,
# Nearest to about: jasmine, locke, quarrelled, culprits, stationery, alligator, ample, workstations,
# Nearest to he: it, they, she, lobos, there, i, who, hugo,
# Nearest to of: in, untso, lilly, for, midwifery, disinformation, adhd, tornadoes,
# Nearest to when: confesses, chirac, kristian, ammonite, porky, philipp, splendour, although,
# Nearest to american: fergus, killed, english, neko, satem, balto, sporadic, cached,
# Nearest to to: organisers, would, cambodia, marmoset, darshan, hospitality, supplied, oromo,
# Nearest to can: would, vanities, may, johnson, will, stahl, disapproved, ballroom,
# Nearest to in: of, at, from, with, on, guppy, for, bassline,
# Nearest to many: some, these, several, such, more, discards, forbidding, most,
# Nearest to his: their, her, the, s, its, muted, posters, minima,
# Nearest to used: lei, clos, jona, kittiwake, unofficially, abolishment, benzoate, bauer,
# Average loss at step 12000: 3.602293
# Average loss at step 14000: 3.571812
# Average loss at step 16000: 3.403333
# Average loss at step 18000: 3.457373
# Average loss at step 20000: 3.543269
# Nearest to the: their, his, its, pompeii, an, a, this, classified,
# Nearest to not: it, to, altering, they, also, who, only, semipalatinsk,
# Nearest to often: also, there, which, it, sometimes, shine, usually, phonetics,
# Nearest to than: or, baleen, harmattan, anthrax, inquisition, producers, tailed, emigration,
# Nearest to are: were, is, was, have, offline, but, be, include,
# Nearest to about: limbic, culprits, jasmine, planar, alligator, locke, frames, engine,
# Nearest to he: it, she, they, who, there, never, radial, sec,
# Nearest to of: catches, untso, proportionality, postmaster, midwifery, for, adhd, in,
# Nearest to when: if, although, after, confesses, chirac, was, in, but,
# Nearest to american: english, french, british, sporadic, canadian, slender, rating, agathon,
# Nearest to to: not, would, can, organisers, could, cannot, may, cambodia,
# Nearest to can: may, would, could, will, must, vanities, to, might,
# Nearest to in: at, on, with, from, and, during, for, by,
# Nearest to many: some, several, these, other, most, all, various, such,
# Nearest to his: their, her, its, the, my, ducal, pacemaker, broome,
# Nearest to used: known, able, bauer, attorneys, difficult, clos, neko, noted,
# Average loss at step 22000: 3.502518
# Average loss at step 24000: 3.492024
# Average loss at step 26000: 3.480735
# Average loss at step 28000: 3.482566
# Average loss at step 30000: 3.509543
# Nearest to the: its, their, his, a, any, some, many, pompeii,
# Nearest to not: they, altering, never, there, still, irl, reliant, harnessed,
# Nearest to often: sometimes, also, usually, there, commonly, still, generally, it,
# Nearest to than: but, baleen, much, for, harmattan, involves, mapping, inquisition,
# Nearest to are: were, is, have, include, tentatively, be, krzy, kart,
# Nearest to about: limbic, frames, locke, culprits, alligator, actual, engine, allophones,
# Nearest to he: she, it, they, who, there, hugo, never, radial,
# Nearest to of: in, untso, main, adhd, awarding, midwifery, geometric, proportionality,
# Nearest to when: if, before, although, after, where, however, is, but,
# Nearest to american: english, british, french, canadian, russian, sporadic, international, national,
# Nearest to to: would, can, organisers, could, will, might, should, cambodia,
# Nearest to can: may, would, could, will, must, might, should, cannot,
# Nearest to in: during, at, within, guppy, from, under, of, since,
# Nearest to many: some, several, these, most, all, such, various, those,
# Nearest to his: their, her, its, the, s, my, ducal, posters,
# Nearest to used: known, able, noted, involved, found, referred, clos, difficult,
# Average loss at step 32000: 3.500399
# Average loss at step 34000: 3.499520
# Average loss at step 36000: 3.453905
# Average loss at step 38000: 3.299041
# Average loss at step 40000: 3.427344
# Nearest to the: its, a, this, their, pompeii, any, each, his,
# Nearest to not: never, they, it, often, also, still, altering, now,
# Nearest to often: usually, also, sometimes, commonly, generally, still, typically, which,
# Nearest to than: or, much, but, deficiencies, models, tav, francophone, radix,
# Nearest to are: were, is, have, include, be, but, tentatively, while,
# Nearest to about: limbic, frames, ic, planar, recruited, actual, substantial, blasphemy,
# Nearest to he: she, it, they, there, who, i, never, subsequently,
# Nearest to of: comprehensive, in, from, clipped, beluga, ruining, where, krakow,
# Nearest to when: if, before, where, although, because, after, is, however,
# Nearest to american: english, canadian, french, british, russian, international, german, european,
# Nearest to to: could, cannot, will, can, might, must, organisers, crooks,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to in: guppy, within, during, from, for, of, at, ericales,
# Nearest to many: some, several, these, most, those, various, such, encyclopedists,
# Nearest to his: their, her, its, my, ducal, the, whose, s,
# Nearest to used: known, found, seen, available, able, held, involved, referred,
# Average loss at step 42000: 3.434476
# Average loss at step 44000: 3.456708
# Average loss at step 46000: 3.449141
# Average loss at step 48000: 3.356974
# Average loss at step 50000: 3.380167
# Nearest to the: its, their, this, a, his, biomass, bangor, somali,
# Nearest to not: never, still, usually, now, nonaligned, generally, it, almost,
# Nearest to often: usually, generally, sometimes, also, commonly, now, still, typically,
# Nearest to than: or, but, deficiencies, much, mapping, far, speedy, parliamentarians,
# Nearest to are: were, have, is, tentatively, those, these, be, include,
# Nearest to about: frames, limbic, recruited, deformed, planar, circumcise, detective, anise,
# Nearest to he: she, it, they, who, there, never, i, then,
# Nearest to of: midwifery, in, and, untso, greatest, postmaster, retorted, including,
# Nearest to when: if, before, after, while, although, however, where, though,
# Nearest to american: canadian, french, russian, english, british, european, international, german,
# Nearest to to: could, should, would, organisers, will, cannot, must, darshan,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to in: within, since, during, until, on, from, of, by,
# Nearest to many: some, several, various, these, those, most, numerous, both,
# Nearest to his: her, their, its, my, whose, the, posters, broome,
# Nearest to used: known, available, seen, referred, able, found, held, written,
# Average loss at step 52000: 3.431708
# Average loss at step 54000: 3.429947
# Average loss at step 56000: 3.438070
# Average loss at step 58000: 3.396719
# Average loss at step 60000: 3.393434
# Nearest to the: their, its, a, each, some, any, pompeii, this,
# Nearest to not: never, still, usually, otherwise, they, now, famagusta, it,
# Nearest to often: usually, sometimes, generally, commonly, also, typically, now, still,
# Nearest to than: but, or, much, deficiencies, and, far, burman, trolley,
# Nearest to are: were, is, have, include, be, tentatively, but, those,
# Nearest to about: limbic, frames, recruited, circumcise, planar, quintessence, anise, on,
# Nearest to he: she, it, they, there, who, later, never, then,
# Nearest to of: same, retorted, midwifery, beluga, in, for, like, proportionality,
# Nearest to when: if, although, before, while, though, after, where, because,
# Nearest to american: british, english, canadian, russian, french, european, german, international,
# Nearest to to: must, cannot, darshan, will, might, would, not, for,
# Nearest to can: may, could, will, would, must, might, cannot, should,
# Nearest to in: within, during, among, since, from, until, at, on,
# Nearest to many: some, several, various, these, most, those, numerous, both,
# Nearest to his: her, their, its, my, whose, ducal, the, gaspard,
# Nearest to used: known, available, seen, held, referred, involved, written, found,
# Average loss at step 62000: 3.243106
# Average loss at step 64000: 3.254380
# Average loss at step 66000: 3.399838
# Average loss at step 68000: 3.398375
# Average loss at step 70000: 3.360419
# Nearest to the: their, its, any, this, a, these, your, each,
# Nearest to not: never, still, now, usually, otherwise, generally, famagusta, almost,
# Nearest to often: usually, sometimes, generally, commonly, now, typically, still, frequently,
# Nearest to than: or, but, deficiencies, much, counterbalance, no, considerably, navigate,
# Nearest to are: were, have, is, tentatively, include, be, those, although,
# Nearest to about: limbic, frames, over, deformed, anise, circumcise, on, planar,
# Nearest to he: she, it, they, there, we, who, then, subsequently,
# Nearest to of: including, untso, in, include, retorted, comprehensive, ruining, and,
# Nearest to when: if, although, while, where, after, though, before, because,
# Nearest to american: british, english, canadian, european, russian, brazilian, french, nous,
# Nearest to to: will, can, might, would, cannot, must, could, darshan,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to in: within, on, during, until, since, including, throughout, for,
# Nearest to many: some, several, various, these, most, numerous, all, such,
# Nearest to his: her, their, its, my, whose, our, blackpool, turkeys,
# Nearest to used: known, available, found, involved, seen, described, held, written,
# Average loss at step 72000: 3.377817
# Average loss at step 74000: 3.347278
# Average loss at step 76000: 3.314055
# Average loss at step 78000: 3.356421
# Average loss at step 80000: 3.377690
# Nearest to the: its, their, pompeii, his, this, any, a, each,
# Nearest to not: never, still, usually, now, sometimes, almost, otherwise, worth,
# Nearest to often: usually, sometimes, generally, commonly, typically, still, now, frequently,
# Nearest to than: or, much, but, burgoyne, and, deficiencies, while, navigate,
# Nearest to are: were, have, is, include, tentatively, although, these, those,
# Nearest to about: limbic, over, frames, circumcise, packer, beaton, kmt, rn,
# Nearest to he: she, it, they, there, we, who, never, dylan,
# Nearest to of: including, retorted, untso, midwifery, eda, awarding, in, beluga,
# Nearest to when: if, before, after, while, although, though, where, during,
# Nearest to american: british, canadian, english, fumble, international, french, nous, brazilian,
# Nearest to to: should, would, will, must, cannot, darshan, can, kangaroos,
# Nearest to can: could, will, may, would, must, might, cannot, should,
# Nearest to in: during, within, until, on, at, since, from, under,
# Nearest to many: some, several, various, these, numerous, most, both, those,
# Nearest to his: her, their, my, its, our, the, your, ducal,
# Nearest to used: known, available, found, written, responsible, seen, referred, described,
# Average loss at step 82000: 3.405566
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-f9ee933dee31> in <module>()
#       9           batch_size, num_skips, skip_window)
#      10         feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11         _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12         average_loss += l
#      13         if step % 2000 == 0:
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    assert batch_size % bag_window == 0
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):        
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(    
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
        
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm 
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.015646
# Nearest to but: annalen, atlas, mawson, forza, nationhood, derive, pretensions, eulemur,
# Nearest to system: monck, brescia, homeostatic, intersection, spade, erodes, yusef, anchoring,
# Nearest to has: nowak, eroding, flattered, administer, maser, ksh, neurath, bodmin,
# Nearest to used: bathe, culture, lily, wheeling, gibberish, stylized, frontman, original,
# Nearest to use: sibyl, wins, threw, jefferson, taps, ewes, prosperity, smile,
# Nearest to were: indonesians, orphanage, tamed, hopf, stalinist, schrader, manoeuvre, sacr,
# Nearest to or: bua, separable, codasyl, conservationist, clarendon, am, heirs, colored,
# Nearest to if: cdm, abdu, theorem, nozick, emotive, noumenon, canonically, photoshop,
# Nearest to known: prevails, asexual, southside, terminating, witt, vijay, slowed, myositis,
# Nearest to that: botham, acoustical, peroxides, reinforce, shari, branding, merits, agreeable,
# Nearest to which: minimum, keeshond, puccini, substantial, zawahiri, tiraspol, hammers, colourful,
# Nearest to i: adequate, austrofascism, pandemonium, north, globalisation, merciful, monologue, haynes,
# Nearest to such: lifeboats, sacramento, encumbered, automobile, sisters, acidity, repulsive, kicked,
# Nearest to by: fabio, cemetery, travis, issa, renegade, shielding, confidently, rotten,
# Nearest to many: fp, mobster, spam, overlap, duckburg, whispered, minestrone, billet,
# Nearest to be: championship, quell, intermixed, basques, bangladesh, dots, torus, electra,
# Average loss at step 2000: 4.472001
# Average loss at step 4000: 3.886293
# Average loss at step 6000: 3.766553
# Average loss at step 8000: 3.605111
# Average loss at step 10000: 3.582143
# Nearest to but: etymologies, lifeless, however, hams, dewey, dolce, radiator, than,
# Nearest to system: brescia, spade, justinian, mantled, intersection, hazy, therapies, suitor,
# Nearest to has: had, have, is, was, bigotry, having, fascinated, borealis,
# Nearest to used: known, referred, considered, censured, required, said, fostering, seen,
# Nearest to use: multiplicative, holiness, needing, prosperity, nigger, limassol, hawk, activate,
# Nearest to were: are, was, have, is, had, pepin, be, secretive,
# Nearest to or: and, windmill, tommy, hoboken, tearing, than, saba, highways,
# Nearest to if: latveria, pontchartrain, mattia, when, dymaxion, slack, atherosclerosis, stad,
# Nearest to known: used, such, name, slovenian, fractured, whistler, resembled, moreno,
# Nearest to that: which, deserted, voltages, this, teborg, what, gradually, agreeable,
# Nearest to which: that, usually, this, it, ostwald, also, threaten, imitates,
# Nearest to i: vcs, necklaces, breastplate, hydrothermal, ii, crooks, they, tendency,
# Nearest to such: well, known, oriole, payment, vater, gulag, huggins, alertness,
# Nearest to by: when, graceful, bodyguard, adamantium, orcs, swede, invalidate, who,
# Nearest to many: some, several, these, all, seeming, hormones, most, both,
# Nearest to be: have, are, maybe, refer, were, alleviating, provide, being,
# Average loss at step 12000: 3.528682
# Average loss at step 14000: 3.523104
# Average loss at step 16000: 3.369674
# Average loss at step 18000: 3.147849
# Average loss at step 20000: 3.219534
# Nearest to but: and, or, etymologies, forked, than, pancakes, however, though,
# Nearest to system: systems, company, brescia, plosive, rear, mantled, lobos, statuette,
# Nearest to has: had, have, having, is, was, cuny, contains, makes,
# Nearest to used: considered, referred, known, seen, found, designed, required, called,
# Nearest to use: move, solvent, limassol, hovered, sadler, response, mid, transports,
# Nearest to were: are, was, had, is, infamously, transitivity, inclusions, being,
# Nearest to or: than, and, but, yucatan, tlp, funnel, thirteen, alembert,
# Nearest to if: where, when, then, concubines, looney, latveria, shielded, cmu,
# Nearest to known: used, such, referred, seen, well, regarded, described, considered,
# Nearest to that: which, what, who, bastiat, this, trujillo, cortes, following,
# Nearest to which: that, this, often, what, where, also, then, who,
# Nearest to i: ii, g, you, we, tendency, exceeded, iii, unchangeable,
# Nearest to such: well, known, referred, payment, vater, huggins, described, seen,
# Nearest to by: when, hongkong, under, amore, brownian, humanoids, ecologically, featureless,
# Nearest to many: some, several, various, all, these, those, both, hormones,
# Nearest to be: refer, have, being, maybe, lead, become, provide, is,
# Average loss at step 22000: 3.365315
# Average loss at step 24000: 3.231369
# Average loss at step 26000: 3.257125
# Average loss at step 28000: 3.308982
# Average loss at step 30000: 3.201444
# Nearest to but: than, saga, plantagenet, though, however, although, and, showcased,
# Nearest to system: systems, conversational, company, justinian, business, plosive, bags, jolley,
# Nearest to has: had, have, having, is, makes, cuny, ritchie, maintains,
# Nearest to used: referred, considered, found, seen, given, known, described, written,
# Nearest to use: produce, because, adequately, hovered, sadler, wary, due, cartoonish,
# Nearest to were: are, was, is, be, inclusions, had, being, include,
# Nearest to or: and, than, brownian, kharkov, philosophicus, amillennialism, secede, magni,
# Nearest to if: when, where, though, without, alike, aubier, concubines, reordering,
# Nearest to known: referred, described, used, such, regarded, considered, seen, well,
# Nearest to that: which, who, ailing, when, bastiat, while, where, bryozoa,
# Nearest to which: that, usually, where, what, still, often, generally, who,
# Nearest to i: you, g, we, they, ii, sultans, neue, ivory,
# Nearest to such: well, known, referred, konami, seen, early, described, vater,
# Nearest to by: under, invalidate, towards, through, generally, when, secured, shamanistic,
# Nearest to many: several, some, various, numerous, both, most, all, those,
# Nearest to be: were, are, belong, refer, provide, decide, is, was,
# Average loss at step 32000: 3.168487
# Average loss at step 34000: 3.151730
# Average loss at step 36000: 3.066245
# Average loss at step 38000: 3.090261
# Average loss at step 40000: 3.093118
# Nearest to but: though, however, although, and, pedagogic, which, idealistic, than,
# Nearest to system: systems, philology, jolley, version, groove, sense, bags, sanskrit,
# Nearest to has: had, have, having, is, contains, includes, makes, was,
# Nearest to used: referred, found, considered, known, written, seen, available, designed,
# Nearest to use: form, bissau, sadler, wheelchair, solvent, isolate, soares, because,
# Nearest to were: are, was, is, being, became, include, infamously, antidisestablishmentarianism,
# Nearest to or: and, than, groucho, kharkov, lugh, gard, benefactor, nanometres,
# Nearest to if: where, though, when, because, before, since, although, pj,
# Nearest to known: referred, used, described, possible, available, seen, regarded, such,
# Nearest to that: which, what, where, when, because, how, bastiat, sothoth,
# Nearest to which: that, what, where, this, who, but, still, these,
# Nearest to i: g, we, you, ii, iii, exceeded, they, srivijaya,
# Nearest to such: well, known, described, follows, far, regarded, opposed, seen,
# Nearest to by: through, estranged, ecologically, towards, among, calcio, hongkong, under,
# Nearest to many: some, several, various, numerous, most, all, manx, newspapers,
# Nearest to be: refer, represent, provide, have, being, maybe, alleviating, lead,
# Average loss at step 42000: 3.108098
# Average loss at step 44000: 3.137966
# Average loss at step 46000: 3.089952
# Average loss at step 48000: 2.969470
# Average loss at step 50000: 3.103944
# Nearest to but: however, although, though, and, because, than, where, while,
# Nearest to system: systems, groove, philology, marketable, program, congregations, reliable, clerical,
# Nearest to has: had, have, contains, having, makes, includes, is, was,
# Nearest to used: referred, found, known, added, designed, available, considered, held,
# Nearest to use: grow, sense, implementation, call, form, return, produce, packets,
# Nearest to were: are, was, is, include, became, had, las, antidisestablishmentarianism,
# Nearest to or: than, and, without, gard, marl, yucatan, stewed, eplf,
# Nearest to if: when, where, because, though, since, then, topmost, thus,
# Nearest to known: referred, used, possible, described, available, regarded, served, seen,
# Nearest to that: which, where, chaparral, paladin, what, bastiat, however, this,
# Nearest to which: that, where, this, what, also, archived, mcelroy, usually,
# Nearest to i: ii, we, you, g, iii, unchangeable, exceeded, mathbb,
# Nearest to such: well, described, far, result, follows, opposed, konami, serve,
# Nearest to by: who, ecologically, under, hongkong, using, omniglot, adamantium, bodleian,
# Nearest to many: some, several, various, all, both, numerous, certain, these,
# Nearest to be: produce, remain, refer, being, have, represent, belong, provide,
# Average loss at step 52000: 3.070528
# Average loss at step 54000: 3.063548
# Average loss at step 56000: 3.086619
# Average loss at step 58000: 3.008825
# Average loss at step 60000: 2.836210
# Nearest to but: although, though, however, which, until, and, than, volt,
# Nearest to system: systems, service, process, program, style, line, bags, marketable,
# Nearest to has: had, have, having, contains, makes, maintains, was, is,
# Nearest to used: referred, considered, designed, available, applied, written, seen, held,
# Nearest to use: form, sense, mix, popularity, forms, outcome, terms, range,
# Nearest to were: are, was, is, include, have, had, became, neanderthal,
# Nearest to or: and, taping, than, adour, exmoor, alembert, marl, bagapsh,
# Nearest to if: when, though, since, because, where, why, although, then,
# Nearest to known: referred, described, used, available, regarded, called, served, seen,
# Nearest to that: which, where, what, why, ailing, who, omniglot, presbyterians,
# Nearest to which: that, what, but, this, who, where, still, also,
# Nearest to i: g, ii, we, iii, you, amines, ruppert, unchangeable,
# Nearest to such: well, result, whole, opposed, described, follows, regarded, known,
# Nearest to by: classrooms, through, among, rhazes, scranton, haihowak, waltham, gracious,
# Nearest to many: some, several, various, numerous, most, all, both, manx,
# Nearest to be: refer, represent, lead, remain, produce, being, occur, provide,
# Average loss at step 62000: 3.030613
# Average loss at step 64000: 3.012495
# Average loss at step 66000: 2.984442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-180-e6c2413a8a48> in <module>()
#       9           batch_size, bag_window)
#      10         feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11         _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12         average_loss += l
#      13         if step % 2000 == 0:
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Users/yusuffadairo/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
