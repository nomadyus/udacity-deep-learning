# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
          'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.327207
# Nearest to may: benchmarking, playlists, gall, bristles, zanzibar, frye, sworn, renovate,
# Nearest to no: blows, britten, sil, hunters, kops, supervision, predication, bamiyan,
# Nearest to it: volcano, merodach, misalignment, subnational, recounts, draws, fairer, evaporated,
# Nearest to be: gradualism, toriyama, maimonides, masala, koenigsegg, toru, america, ravi,
# Nearest to UNK: rolled, attitude, reactors, hitman, banning, reassessment, realizes, hh,
# Nearest to also: cookbook, basayev, kosova, francophones, collegium, assailants, armageddon, nite,
# Nearest to most: renovated, triangular, schaefer, frick, americans, anchored, chute, maka,
# Nearest to that: sprites, fevers, glosses, update, brat, lynching, numerically, interval,
# Nearest to he: quarter, pwnage, expressionism, miggins, limestone, marxists, rally, wolfhound,
# Nearest to so: centers, broadsword, conformal, mad, onto, ineffectiveness, knowable, clutches,
# Nearest to first: discerned, placement, superset, ridley, blockaded, auctions, platelets, attar,
# Nearest to while: hugo, sophie, despotic, decreasing, hamill, dweller, decarlo, dictatorships,
# Nearest to b: repelling, vassal, baltic, properly, perjury, woo, conduit, communally,
# Nearest to its: notables, summers, islamabad, ari, hemorrhagic, feminists, ignorant, gwadar,
# Nearest to known: eurocard, music, dusty, quote, kava, chagrin, sulpicius, translation,
# Nearest to used: amal, sioux, transference, sima, anarcho, coulter, accept, mk,
# Average loss at step 2000: 4.365512
# Average loss at step 4000: 3.873433
# Average loss at step 6000: 3.788822
# Average loss at step 8000: 3.681067
# Average loss at step 10000: 3.619846
# Nearest to may: can, would, supplied, playlists, benchmarking, could, juicy, were,
# Nearest to no: retainers, kenilworth, blows, sada, another, ifbb, scorpion, ade,
# Nearest to it: he, this, which, there, they, not, that, also,
# Nearest to be: have, been, is, was, econometric, by, are, refer,
# Nearest to UNK: caesars, reactors, accommodates, copylefted, de, participated, robert, newborns,
# Nearest to also: often, not, it, which, sabotage, rumours, physicalism, followings,
# Nearest to most: schaefer, names, many, triangular, anchored, more, ionized, americans,
# Nearest to that: which, this, it, triggering, lynching, believable, landscape, who,
# Nearest to he: it, they, she, who, sedimentation, heyerdahl, mush, cohesion,
# Nearest to so: onto, broadsword, conformal, sonnets, found, knowable, fca, primarily,
# Nearest to first: placement, discerned, next, yersinia, soviet, tonkin, primate, mcduck,
# Nearest to while: sophie, and, once, matres, epistemic, logbook, decreasing, hugo,
# Nearest to b: d, vassal, repelling, baltic, perjury, ibero, communally, countess,
# Nearest to its: their, the, his, notables, a, reverend, bongo, her,
# Nearest to known: eurocard, music, superconductor, sugarcubes, schubert, terminated, quote, dusty,
# Nearest to used: seen, amal, humanae, unusually, common, sing, cartoonish, dane,
# Average loss at step 12000: 3.606233
# Average loss at step 14000: 3.570451
# Average loss at step 16000: 3.405162
# Average loss at step 18000: 3.454598
# Average loss at step 20000: 3.543069
# Nearest to may: can, would, could, must, will, should, cannot, to,
# Nearest to no: another, scorpion, retainers, ifbb, blows, sada, any, passive,
# Nearest to it: he, there, this, which, they, she, vh, not,
# Nearest to be: have, is, been, by, was, were, become, libido,
# Nearest to UNK: cellar, cimeti, tritone, oxford, participated, resistor, recoil, overwhelming,
# Nearest to also: which, often, not, who, sabotage, quite, usually, it,
# Nearest to most: more, some, many, medicine, quelled, names, americans, ionized,
# Nearest to that: which, what, when, but, lynching, landscape, gait, however,
# Nearest to he: it, she, they, who, sedimentation, there, never, chaplain,
# Nearest to so: onto, conformal, but, ineffectiveness, mad, primarily, sonnets, fca,
# Nearest to first: next, mcduck, second, discerned, fetishism, earned, yersinia, akiva,
# Nearest to while: sulfate, or, epistemic, and, decreasing, dualistic, discredit, matres,
# Nearest to b: d, vassal, mychal, repelling, sissy, absurdum, vindication, oxidizing,
# Nearest to its: their, his, her, the, some, notables, incarcerated, bongo,
# Nearest to known: used, eurocard, music, such, well, sugarcubes, superconductor, cited,
# Nearest to used: seen, known, unusually, sima, reuel, sing, dane, barr,
# Average loss at step 22000: 3.502995
# Average loss at step 24000: 3.485565
# Average loss at step 26000: 3.480316
# Average loss at step 28000: 3.481531
# Average loss at step 30000: 3.501093
# Nearest to may: can, would, could, must, will, should, cannot, might,
# Nearest to no: any, another, ifbb, a, sada, blows, scorpion, predication,
# Nearest to it: he, there, this, she, which, they, also, vh,
# Nearest to be: have, been, are, were, is, hindenburg, become, being,
# Nearest to UNK: cimeti, disgusting, jumbled, doj, rahul, gora, cellar, lingus,
# Nearest to also: often, which, it, here, still, usually, always, who,
# Nearest to most: more, many, some, medicine, americans, wilford, quelled, names,
# Nearest to that: which, what, however, this, but, where, when, faceted,
# Nearest to he: she, they, it, who, sedimentation, there, never, aurangzeb,
# Nearest to so: conformal, primarily, onto, mad, more, extremely, kista, skewed,
# Nearest to first: next, second, mcduck, last, fetishism, same, discerned, ground,
# Nearest to while: is, once, but, however, excluding, and, after, sulfate,
# Nearest to b: d, merck, sissy, mychal, vassal, morel, primed, vindication,
# Nearest to its: their, his, the, her, notables, incarcerated, some, bongo,
# Nearest to known: used, well, such, defined, eurocard, sugarcubes, regarded, cited,
# Nearest to used: known, referred, seen, found, designed, allergic, sima, proven,
# Average loss at step 32000: 3.503287
# Average loss at step 34000: 3.491211
# Average loss at step 36000: 3.459874
# Average loss at step 38000: 3.299147
# Average loss at step 40000: 3.431405
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to no: any, another, blows, predication, ifbb, scorpion, nara, angelo,
# Nearest to it: he, there, this, she, they, which, not, but,
# Nearest to be: been, have, being, was, are, is, become, were,
# Nearest to UNK: swiss, crazy, fresnel, victor, jacob, fictionalized, othello, evocative,
# Nearest to also: which, often, usually, still, generally, below, here, always,
# Nearest to most: more, some, many, ionized, medicine, names, less, americans,
# Nearest to that: which, this, what, however, reflection, when, where, rodin,
# Nearest to he: she, it, they, there, who, sedimentation, i, aurangzeb,
# Nearest to so: conformal, kista, thrush, mad, belatedly, but, apocr, onto,
# Nearest to first: next, second, last, mcduck, fetishism, same, discerned, formic,
# Nearest to while: when, after, but, and, before, once, although, however,
# Nearest to b: d, r, c, melbourne, motorola, appreciated, morel, primed,
# Nearest to its: their, his, the, her, reverend, theologically, ryle, showgirl,
# Nearest to known: such, used, defined, eurocard, well, referred, regarded, cited,
# Nearest to used: found, known, referred, seen, designed, common, allergic, hedge,
# Average loss at step 42000: 3.434784
# Average loss at step 44000: 3.455113
# Average loss at step 46000: 3.451280
# Average loss at step 48000: 3.356449
# Average loss at step 50000: 3.384354
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to no: any, another, blows, federative, thursday, stipend, she, ifbb,
# Nearest to it: he, there, she, this, they, generally, now, authorised,
# Nearest to be: have, been, become, being, are, was, were, is,
# Nearest to UNK: de, robert, publicacion, lasker, bi, normed, l, menelik,
# Nearest to also: which, often, still, who, here, now, generally, engenders,
# Nearest to most: more, less, wilford, some, many, medicine, guadeloupe, quelled,
# Nearest to that: which, however, what, this, amps, observing, but, superstars,
# Nearest to he: she, it, they, who, there, sedimentation, never, aurangzeb,
# Nearest to so: conformal, belatedly, omer, if, thrush, fibreglass, then, mad,
# Nearest to first: second, last, next, mcduck, earliest, almohad, third, during,
# Nearest to while: when, however, after, but, although, before, though, and,
# Nearest to b: d, motorola, c, terminator, mychal, r, morel, langer,
# Nearest to its: their, his, the, her, incarcerated, reverend, your, s,
# Nearest to known: used, defined, such, eurocard, regarded, well, referred, grenville,
# Nearest to used: known, designed, referred, seen, found, given, allergic, portrayed,
# Average loss at step 52000: 3.437154
# Average loss at step 54000: 3.429605
# Average loss at step 56000: 3.438406
# Average loss at step 58000: 3.394998
# Average loss at step 60000: 3.392346
# Nearest to may: can, will, would, could, might, must, should, cannot,
# Nearest to no: any, little, thursday, federative, another, a, blows, lesh,
# Nearest to it: there, he, she, this, which, they, what, that,
# Nearest to be: been, have, become, is, being, was, were, produce,
# Nearest to UNK: physicalism, stumbling, slogan, farming, forgotten, singaporean, baritone, destroyed,
# Nearest to also: often, now, still, which, here, usually, generally, below,
# Nearest to most: more, some, many, less, guadeloupe, medicine, use, especially,
# Nearest to that: which, however, this, what, it, lyne, diagrams, superstars,
# Nearest to he: she, it, they, there, never, who, soon, we,
# Nearest to so: conformal, if, fibreglass, then, thrush, extremely, decibels, things,
# Nearest to first: last, second, next, best, same, third, mcduck, earliest,
# Nearest to while: when, although, after, before, though, however, but, akihito,
# Nearest to b: d, motorola, morel, r, p, m, joaquim, outages,
# Nearest to its: their, his, the, her, reverend, your, bongo, incarcerated,
# Nearest to known: used, such, defined, regarded, eurocard, well, referred, recorded,
# Nearest to used: known, designed, referred, seen, found, called, written, described,
# Average loss at step 62000: 3.240199
# Average loss at step 64000: 3.257646
# Average loss at step 66000: 3.406859
# Average loss at step 68000: 3.394397
# Average loss at step 70000: 3.360457
# Nearest to may: can, will, could, would, might, must, should, cannot,
# Nearest to no: any, little, thursday, federative, significant, considerably, antares, there,
# Nearest to it: he, she, there, this, they, which, still, generally,
# Nearest to be: been, become, being, is, have, were, was, are,
# Nearest to UNK: monoxide, wordplay, disproportionately, fictionalized, dlr, regains, passport, e,
# Nearest to also: still, often, which, now, below, here, usually, useable,
# Nearest to most: more, less, many, some, use, guadeloupe, particularly, especially,
# Nearest to that: which, however, what, this, but, superstars, usually, often,
# Nearest to he: she, it, they, who, there, never, sedimentation, soon,
# Nearest to so: thrush, then, belatedly, kista, conformal, fibreglass, deleted, if,
# Nearest to first: last, second, next, mcduck, best, third, same, original,
# Nearest to while: although, when, before, though, and, however, after, but,
# Nearest to b: d, f, morel, motorola, p, z, r, n,
# Nearest to its: their, his, the, her, incarcerated, your, redirection, arcologies,
# Nearest to known: used, such, defined, regarded, well, eurocard, recorded, classified,
# Nearest to used: known, designed, found, referred, seen, described, written, available,
# Average loss at step 72000: 3.375416
# Average loss at step 74000: 3.349035
# Average loss at step 76000: 3.318354
# Average loss at step 78000: 3.353160
# Average loss at step 80000: 3.379536
# Nearest to may: can, will, could, would, might, must, should, cannot,
# Nearest to no: any, ringo, little, lesh, rim, federative, errol, windshield,
# Nearest to it: he, she, there, this, they, we, cicero, prosecutions,
# Nearest to be: been, have, become, being, are, were, smartest, blackberry,
# Nearest to UNK: johnson, jaroslav, victoria, unsuspecting, doj, darwin, mcfarland, thug,
# Nearest to also: often, still, now, which, never, sometimes, occasionally, here,
# Nearest to most: some, more, many, guadeloupe, less, winds, particularly, sip,
# Nearest to that: which, however, what, freie, but, invasive, heated, reorganize,
# Nearest to he: she, it, they, there, who, never, sedimentation, we,
# Nearest to so: thrush, kista, deleted, then, if, too, conformal, leahy,
# Nearest to first: last, second, third, next, mcduck, same, freiherr, gilbertese,
# Nearest to while: although, when, though, after, before, and, however, aventine,
# Nearest to b: d, joaquim, morel, susie, ga, c, m, terminator,
# Nearest to its: their, his, her, the, your, incarcerated, our, sabres,
# Nearest to known: used, defined, regarded, such, cited, available, well, recorded,
# Nearest to used: known, referred, designed, found, seen, described, available, written,
# Average loss at step 82000: 3.406519
# Average loss at step 84000: 3.409462
# Average loss at step 86000: 3.390188
# Average loss at step 88000: 3.360048
# Average loss at step 90000: 3.365960
# Nearest to may: can, could, will, would, might, should, must, cannot,
# Nearest to no: any, little, ringo, nothing, considerably, significant, reasonable, another,
# Nearest to it: he, she, there, this, they, prosecutions, we, generally,
# Nearest to be: become, been, being, have, easily, was, is, smartest,
# Nearest to UNK: costa, haze, fenrir, imo, relieves, bottle, longue, barbara,
# Nearest to also: still, often, which, now, generally, never, sometimes, actually,
# Nearest to most: more, some, many, less, guadeloupe, particularly, several, use,
# Nearest to that: which, however, what, but, amps, tori, brakeman, declination,
# Nearest to he: she, it, they, there, who, later, sedimentation, chaplain,
# Nearest to so: thus, too, if, belatedly, leahy, thrush, conformal, casuistry,
# Nearest to first: last, second, third, next, mcduck, earliest, same, original,
# Nearest to while: although, when, before, though, after, however, were, until,
# Nearest to b: d, morel, joaquim, motorola, letter, p, epsilon, c,
# Nearest to its: their, his, her, the, your, our, reverend, whose,
# Nearest to known: used, such, regarded, defined, available, well, cited, scrip,
# Nearest to used: designed, known, referred, seen, described, found, interpreted, called,
# Average loss at step 92000: 3.401325
# Average loss at step 94000: 3.253229
# Average loss at step 96000: 3.361928
# Average loss at step 98000: 3.243768
# Average loss at step 100000: 3.362357
# Nearest to may: can, could, would, must, might, should, will, cannot,
# Nearest to no: any, little, ringo, nothing, another, antares, federative, only,
# Nearest to it: he, she, this, there, they, prosecutions, often, generally,
# Nearest to be: been, have, being, become, easily, are, is, hermetical,
# Nearest to UNK: nite, facilitation, cyclopedia, disgusting, regains, messy, functors, dystopia,
# Nearest to also: still, often, never, now, generally, sometimes, actually, usually,
# Nearest to most: more, less, particularly, especially, some, guadeloupe, many, among,
# Nearest to that: which, what, however, who, but, fevers, why, rodin,
# Nearest to he: she, it, they, there, who, sedimentation, we, never,
# Nearest to so: thus, too, therefore, if, justus, then, conformal, thrush,
# Nearest to first: last, second, next, third, mcduck, same, earliest, fourth,
# Nearest to while: although, when, though, before, after, and, but, are,
# Nearest to b: d, morel, singh, epsilon, joaquim, ernest, motorola, sissy,
# Nearest to its: their, his, the, her, your, our, whose, proportionately,
# Nearest to known: defined, such, regarded, used, possible, available, well, recorded,
# Nearest to used: designed, referred, found, known, seen, written, given, described,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
